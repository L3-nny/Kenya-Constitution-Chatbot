# %% [markdown]
# ## import libraries

# %%
import re
import pdfplumber
import spacy

# %%
# Path to the PDF file
pdf_path = "C:/Users/PC/Documents/FLATIRON/PHASE5/Kenya-Constitution-Chatbot/Kenya Constitution.pdf"

with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        text = page.extract_text()

# %% [markdown]
# ### creating a function that will help to iterate text using the page number

# %%
# Path to your PDF file
pdf_path = "C:/Users/PC/Documents/FLATIRON/PHASE5/Kenya-Constitution-Chatbot/Kenya Constitution.pdf"

# Function to extract text from specific pages
def extract_specific_pages(cleaned_constitution, start_page, end_page):
    with pdfplumber.open(cleaned_constitution) as pdf:
        extracted_text = ""
        for page_num in range(start_page, end_page):
            page = pdf.pages[page_num]
            extracted_text += page.extract_text() + "\n"
        return extracted_text

# %% [markdown]
# ## Chapter 4
#
# ### The bill of rights

# %%
# extracting the whole of chapter 4 which is located in page 18 to 41
chapter_4 = extract_specific_pages(pdf_path, 18,41 )
chapter_4
# Out:
# 'Constitution of Kenya, 2010 19\n(c) the age of the person becomes known, and reveals that the\nperson was older than eight years when found in Kenya.\nLegislation on citizenship.\n18. Parliament shall enact legislation—\n(a) prescribing procedures by which a person may become a\ncitizen;\n(b) governing entry into and residence in Kenya;\n(c) providing for the status of permanent residents;\n(d) providing for voluntary renunciation of citizenship;\n(e) prescribing procedures for revocation of citizenship;\n(f) prescribing the duties and rights of citizens; and\n(g) generally giving effect to the provisions of this Chapter.\nCHAPTER FOUR—THE BILL OF RIGHTS\nPART 1—GENERAL PROVISIONS RELATING TO THE BILL OF RIGHTS\nRights and fundamental freedoms.\n19. (1) The Bill of Rights is an integral part of Kenya’s democratic\nstate and is the framework for social, economic and cultural policies.\n(2) The purpose of recognising and protecting human rights and\nfundamental freedoms is to preserve
# ...

# %% [markdown]
# ### The chapter 4 starts at page 19, which is shared by the end of chapter 3 and ends at page 41 and still the page is split into two thats is one partof the page is the start of chapter 5, we have to split this inorder to have just the info of chapter 4.

# %%
# remove chapter 3 and chapter 5 in pages 18 and 41 respectively, remain with chapter 4 alone
chapter_4_trimmed = chapter_4.split("CHAPTER FOUR", 1)[1].split("CHAPTER FIVE", 1)[0].strip()

print(chapter_4_trimmed)
# Out:
# —THE BILL OF RIGHTS
# PART 1—GENERAL PROVISIONS RELATING TO THE BILL OF RIGHTS
# Rights and fundamental freedoms.
# 19. (1) The Bill of Rights is an integral part of Kenya’s democratic
# state and is the framework for social, economic and cultural policies.
# (2) The purpose of recognising and protecting human rights and
# fundamental freedoms is to preserve the dignity of individuals and
# communities and to promote social justice and the realisation of the
# potential of all human beings.
# (3) The rights and fundamental freedoms in the Bill of Rights—
# (a) belong to each individual and are not granted by the State;
# (b) do not exclude other rights and fundamental freedoms not in
# the Bill of Rights, but recognised or conferred by law, except
# to the extent that they are inconsistent with this Chapter; and
# (c) are subject only to the limitations contemplated in this
# Constitution.
# Application of Bill of Rights.
# ...

# %%
# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Preprocess the user query using spaCy
def preprocess_query(query):
    # Parse the query with spaCy
    doc = nlp(query)
    # Normalize the query: lowercase, lemmatize, and remove stopwords
    tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(tokens)

# Example usage of the preprocessing function
user_query = "What is the supremacy of the constitution?"
processed_query = preprocess_query(user_query)
print(processed_query)
# Out:
# supremacy constitution

# %% [markdown]
# Spliting chapter 4 into section

# %%
def split_chapter_4(chapter_text):
    # Split at key headings and strip extra whitespace
    sections = {
        "fundamental freedoms": [],
        "Application of Bill": [],
        "Implementation of rights": [],
        "Enforcement of Bill": [],
        "courts": [],
        "Limitation of rights": [],
        "Fundamental Rights": [],
        "life": [],
        "Equality": [],
        "dignity": [],
        "security": [],
        "Slavery": [],
        "Privacy": [],
        "conscience": [],
        "expression": [],
        "media": [],
        "information": [],
        "association": [],
        "Assembly, demonstration, picketing and petition": [],
        "Political": [],
        "movement": [],
        "property": [],
        "Labour": [],
        "Environment": [],
        "Economic": [],
        "Language": [],
        "Family": [],
        "Consumer": [],
        "administrative": [],
        "justice": [],
        "arrested": [],
        "hearing": [],
        "custody": [],
        "Interpretation of this Part": [],
        "Children": [],
        "disabilities": [],
        "Youth": [],
        "marginalised": [],
        "Older": [],
        "emergency": [],
        "National Human Rights": []
    }

    # Split by new lines to process line by line
    lines = chapter_text.splitlines()

    current_section = None

    for line in lines:
        stripped_line = line.strip()

        if stripped_line.startswith("Rights and fundamental freedoms"):
            current_section = "fundamental freedoms"
        elif stripped_line.startswith("Application of Bill of Rights"):
            current_section = "Application of Bill"
        elif stripped_line.startswith("Implementation of rights and fundamental freedoms"):
            current_section = "Implementation of rights"
        elif stripped_line.startswith("Enforcement of Bill of Rights"):
            current_section = "Enforcement of Bill"
        elif stripped_line.startswith("Authority of courts to uphold and enforce the Bill of Rights"):
            current_section = "courts"
        elif stripped_line.startswith("Limitation of rights and fundamental freedoms"):
            current_section = "Limitation of rights"
        elif stripped_line.startswith("Fundamental Rights and freedoms that may not be limited"):
            current_section = "Fundamental Rights"
        elif stripped_line.startswith("Right to life"):
            current_section = "life"
        elif stripped_line.startswith("Equality and freedom from discrimination"):
            current_section = "Equality"
        elif stripped_line.startswith("Human dignity"):
            current_section = "dignity"
        elif stripped_line.startswith("Freedom and security of the person"):
            current_section = "security"
        elif stripped_line.startswith("Slavery, servitude and forced labour"):
            current_section = "Slavery"
        elif stripped_line.startswith("Privacy"):
            current_section = "Privacy"
        elif stripped_line.startswith("Freedom of conscience, religion, belief and opinion"):
            current_section = "conscience"
        elif stripped_line.startswith("Freedom of expression"):
            current_section = "expression"
        elif stripped_line.startswith("Freedom of the media"):
            current_section = "media"
        elif stripped_line.startswith("Access to information"):
            current_section = "information"
        elif stripped_line.startswith("Freedom of association"):
            current_section = "association"
        elif stripped_line.startswith("Assembly, demonstration, picketing and petition"):
            current_section = "Assembly, demonstration, picketing and petition"
        elif stripped_line.startswith("Political rights"):
            current_section = "Political"
        elif stripped_line.startswith("Freedom of movement and residence"):
            current_section = "movement"
        elif stripped_line.startswith("Protection of right to property"):
            current_section = "property"
        elif stripped_line.startswith("Labour relations"):
            current_section = "Labour"
        elif stripped_line.startswith("Environment"):
            current_section = "Environment"
        elif stripped_line.startswith("Economic and social rights"):
            current_section = "Economic"
        elif stripped_line.startswith("Language and culture"):
            current_section = "Language"
        elif stripped_line.startswith("Family"):
            current_section = "Family"
        elif stripped_line.startswith("Consumer rights"):
            current_section = "Consumer"
        elif stripped_line.startswith("Fair administrative action"):
            current_section = "administrative"
        elif stripped_line.startswith("Access to justice"):
            current_section = "justice"
        elif stripped_line.startswith("Rights of arrested persons"):
            current_section = "arrested"
        elif stripped_line.startswith("Fair hearing"):
            current_section = "hearing"
        elif stripped_line.startswith("Rights of persons detained, held in custody or imprisoned"):
            current_section = "custody"
        elif stripped_line.startswith("Interpretation of this Part"):
            current_section = "Interpretation of this Part"
        elif stripped_line.startswith("Children"):
            current_section = "Children"
        elif stripped_line.startswith("Persons with disabilities"):
            current_section = "disabilities"
        elif stripped_line.startswith("Youth"):
            current_section = "Youth"
        elif stripped_line.startswith("Minorities and marginalised groups"):
            current_section = "marginalised"
        elif stripped_line.startswith("Older members of society"):
            current_section = "Older"
        elif stripped_line.startswith("State of emergency"):
            current_section = "emergency"
        elif stripped_line.startswith("Kenya National Human Rights and Equality Commission"):
            current_section = "National Human Rights"
        # Append line to the current section if it's set
        if current_section:
            sections[current_section].append(stripped_line)

    # Join each section into a single string
    for key in sections:
        sections[key] = "\n".join(sections[key])

    return sections

# Split the chapter into sections
chapter_4_sections = split_chapter_4(chapter_4_trimmed)

print("fundamental freedoms Section:\n", chapter_4_sections['fundamental freedoms'])
print("\nInterpretation of this Part Section:\n", chapter_4_sections['Interpretation of this Part'])
print("\nNational Human Rights Section:\n", chapter_4_sections['National Human Rights'])
# Out:
# fundamental freedoms Section:
#  Rights and fundamental freedoms.
# 19. (1) The Bill of Rights is an integral part of Kenya’s democratic
# state and is the framework for social, economic and cultural policies.
# (2) The purpose of recognising and protecting human rights and
# fundamental freedoms is to preserve the dignity of individuals and
# communities and to promote social justice and the realisation of the
# potential of all human beings.
# (3) The rights and fundamental freedoms in the Bill of Rights—
# (a) belong to each individual and are not granted by the State;
# (b) do not exclude other rights and fundamental freedoms not in
# the Bill of Rights, but recognised or conferred by law, except
# to the extent that they are inconsistent with this Chapter; and
# (c) are subject only to the limitations contemplated in this
# Constitution.
#
# Interpretation of this Part Section:
#  Interpretation of this Part.
# 52. (1) This Part elaborates certain rights to ensure greater
# ...

# %%
chapter_4_sections
# Out:
# {'fundamental freedoms': 'Rights and fundamental freedoms.\n19. (1) The Bill of Rights is an integral part of Kenya’s democratic\nstate and is the framework for social, economic and cultural policies.\n(2) The purpose of recognising and protecting human rights and\nfundamental freedoms is to preserve the dignity of individuals and\ncommunities and to promote social justice and the realisation of the\npotential of all human beings.\n(3) The rights and fundamental freedoms in the Bill of Rights—\n(a) belong to each individual and are not granted by the State;\n(b) do not exclude other rights and fundamental freedoms not in\nthe Bill of Rights, but recognised or conferred by law, except\nto the extent that they are inconsistent with this Chapter; and\n(c) are subject only to the limitations contemplated in this\nConstitution.',
# ...

# %%
# Define the sections variable with Chapter 1
sections = chapter_4_sections  # Assuming chapter_1 contains the text extracted from the PDF

# Define the QA mapping based on key phrases and corresponding sections
qa_mapping = {
    "fundamental freedoms": "Rights and fundamental freedoms",
    "Application of Bill": "Application of Bill of Rights", 
    "Implementation of rights": "Implementation of rights and fundamental freedoms", 
    "Enforcement of Bill": "Enforcement of Bill of Rights", 
    "courts": "Authority of courts to uphold and enforce the Bill of Rights", 
    "Limitation of rights": "Limitation of rights and fundamental freedoms", 
    "Fundamental Rights": "Fundamental Rights and freedoms that may not be limited", 
    "life": "Right to life", 
    "Equality": "Equality and freedom from discrimination", 
    "dignity": "Human dignity", 
    "security": "Freedom and security of the person", 
    "Slavery": "Slavery, servitude and forced labour", 
    "Privacy": "Privacy", 
    "conscience": "Freedom of conscience, religion, belief and opinion", 
    "expression": "Freedom of expression", 
    "media": "Freedom of the media", 
    "information": "Access to information", 
    "association": "Freedom of association", 
    "Assembly, demonstration, picketing and petition": "Assembly, demonstration, picketing and petition", 
    "Politicals": "Political rights", 
    "movement": "Freedom of movement and residence", 
    "property": "Protection of right to property", 
    "Labour": "Labour relations", 
    "Environment": "Environment", 
    "Economic": "Economic and social rights", 
    "Language": "Language and culture", 
    "Family": "Family", 
    "Consumer": "Consumer rights", 
    "administrative": "Fair administrative action", 
    "justice": "Access to justice" ,
    "arrested": "Rights of arrested persons", 
    "hearing": "Fair hearing", 
    "custody": "Rights of persons detained, held in custody or imprisoned", 
    "Interpretation of this Part": "Interpretation of this Part", 
    "Children": "Children", 
    "disabilities": "Persons with disabilities", 
    "Youth": "Youth", 
    "marginalised": "Minorities and marginalised groups", 
    "Older": "Older members of society", 
    "emergency": "State of emergency",
    "National Human Rights": "Kenya National Human Rights and Equality Commission"
}

# Update the Q&A system to use preprocessed queries
##define the preprocess query function
def preprocess_query(query):
    return query.lower()  # Ensure case-insensitive matching

# Fix the answer_question_nlp function
def answer_question_nlp(query):
    # Preprocess the query
    preprocessed_query = preprocess_query(query)

    # Search for a matching key in QA_mapping
    for key, value in qa_mapping.items():
        if key.lower() in preprocessed_query:
            # Return the relevant section using the shorter section key (e.g., "Rights")
            return sections[key]  

    return "Sorry, I couldn't find an answer to your question."

# Example query
user_query = "discuss Interpretation of this Part"
answer = answer_question_nlp(user_query)
print(answer)
# Out:
# Interpretation of this Part.
# 52. (1) This Part elaborates certain rights to ensure greater
# certainty as to the application of those rights and fundamental
# freedoms to certain groups of persons.
# (2) This Part shall not be construed as limiting or qualifying any
# right.

# %% [markdown]
# ### Chapter 5
#
# ### Land and Environment

# %%
# extracting the whole of chapter 4 which is located in page 41 to 48
chapter_5 = extract_specific_pages(pdf_path, 40, 48)
chapter_5
# Out:
# 'Constitution of Kenya, 2010 41\n(j) to report on complaints investigated under paragraphs (h) and\n(i) and take remedial action; and\n(k) to perform any other functions prescribed by legislation.\n(3) Every person has the right to complain to the Commission,\nalleging that a right or fundamental freedom in the Bill of Rights has\nbeen denied, violated or infringed, or is threatened.\n(4) Parliament shall enact legislation to give full effect to this Part,\nand any such legislation may restructure the Commission into two or\nmore separate commissions.\n(5) If Parliament enacts legislation restructuring the Commission\nunder clause (4)—\n(a) that legislation shall assign each function of the Commission\nspecified in this Article to one or the other of the successor\ncommissions;\n(b) each of the successor commissions shall have powers\nequivalent to the powers of the Commission under this\nArticle; and\n(c) each successor commission shall be a commission within the\nmeaning of Chapter
# ...

# %% [markdown]
# ### The chapter 5 starts at page 41, which is shared by the end of chapter 4 and ends at page 41 and still the page is split into two thats is one partof the page is the start of chapter 6, we have to split this inorder to have just the info of chapter 5.

# %%
# remove chapter 4 and chapter 6 in pages 41 and 48 respectively, remain with chapter 4 alone
chapter_5_trimmed = chapter_5.split("CHAPTER FIVE", 1)[1].split("CHAPTER SIX", 1)[0].strip()

print(chapter_5_trimmed)
# Out:
# —LAND AND ENVIRONMENT
# PART 1—LAND
# Principles of land policy.
# 60. (1) Land in Kenya shall be held, used and managed in a
# manner that is equitable, efficient, productive and sustainable, and in
# accordance with the following principles—
# (a) equitable access to land;
# (b) security of land rights;
# (c) sustainable and productive management of land resources;
# (d) transparent and cost effective administration of land;
# (e) sound conservation and protection of ecologically sensitive
# areas;
# 42 Constitution of Kenya, 2010
# (f) elimination of gender discrimination in law, customs and
# practices related to land and property in land; and
# (g) encouragement of communities to settle land disputes
# through recognised local community initiatives consistent with
# this Constitution.
# (2) These principles shall be implemented through a national land
# policy developed and reviewed regularly by the national government
# and through legislation.
# Classification of land.
# ...

# %%
# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Preprocess the user query using spaCy
def preprocess_query(query):
    # Parse the query with spaCy
    doc = nlp(query)
    # Normalize the query: lowercase, lemmatize, and remove stopwords
    tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(tokens)

# Example usage of the preprocessing function
user_query = "What is the supremacy of the constitution?"
processed_query = preprocess_query(user_query)
print(processed_query)
# Out:
# supremacy constitution

# %%
def split_chapter_5(chapter_text):
    # Split at key headings and strip extra whitespace
    sections = {
        "Principles of land": [],
        "Classification of land": [],
        "Public land": [],
        "Community land": [],
        "Private land": [],
        "Landholding": [],
        "Regulation of land": [],
        "Land Commission": [],
        "Legislation on land": [],
        "Obligations in respect of the environment": [],
        "Enforcement of environmental rights": [],
        "natural resource": [],
        "Legislation relating to the environment": []
        
    }

    # Split by new lines to process line by line
    lines = chapter_text.splitlines()

    current_section = None

    for line in lines:
        stripped_line = line.strip()

        if stripped_line.startswith("Principles of land policy"):
            current_section = "Principles of land"
        elif stripped_line.startswith("Classification of land"):
            current_section = "Classification of land"
        elif stripped_line.startswith("Public land"):
            current_section = "Public land"
        elif stripped_line.startswith("Community land"):
            current_section = "Community land"
        elif stripped_line.startswith("Private land"):
            current_section = "Private land"
        elif stripped_line.startswith("Landholding by non-citizens"):
            current_section = "Landholding"
        elif stripped_line.startswith("Regulation of land use and property"):
            current_section = "Regulation of land"
        elif stripped_line.startswith("National Land Commission"):
            current_section = "Land Commission"
        elif stripped_line.startswith("Legislation on land"):
            current_section = "Legislation on land"
        elif stripped_line.startswith("Obligations in respect of the environment"):
            current_section = "Obligations in respect of the environment"
        elif stripped_line.startswith("Enforcement of environmental rights"):
            current_section = "Enforcement of environmental rights"
        elif stripped_line.startswith("Agreements relating to natural resource"):
            current_section = "natural resource"
        elif stripped_line.startswith("Legislation relating to the environment"):
            current_section = "Legislation relating to the environment"
        # Append line to the current section if it's set
        if current_section:
            sections[current_section].append(stripped_line)

    # Join each section into a single string
    for key in sections:
        sections[key] = "\n".join(sections[key])

    return sections

# Split the chapter into sections
chapter_5_sections = split_chapter_5(chapter_5_trimmed)

print("Legislation relating to the environment Section:\n", chapter_5_sections['Legislation relating to the environment'])
print("\nnatural resources Section:\n", chapter_5_sections['natural resource'])
print("\nEnforcement of environmental rights Section:\n", chapter_5_sections['Enforcement of environmental rights'])
# Out:
# Legislation relating to the environment Section:
#  Legislation relating to the environment.
# 72. Parliament shall enact legislation to give full effect to the
# provisions of this Part.
#
# natural resources Section:
#  Agreements relating to natural resource.
# 71. (1) A transaction is subject to ratification by Parliament if it—
# (a) involves the grant of a right or concession by or on behalf of
# any person, including the national government, to another
# person for the exploitation of any natural resource of Kenya;
# and
# 48 Constitution of Kenya, 2010
# (b) is entered into on or after the effective date.
# (2) Parliament shall enact legislation providing for the classes of
# transactions subject to ratification under clause (1).
#
# Enforcement of environmental rights Section:
#  Enforcement of environmental rights.
# 70. (1) If a person alleges that a right to a clean and healthy
# environment recognised and protected under Article 42 has been, is
# ...

# %%
chapter_5_sections
# Out:
# {'Principles of land': 'Principles of land policy.\n60. (1) Land in Kenya shall be held, used and managed in a\nmanner that is equitable, efficient, productive and sustainable, and in\naccordance with the following principles—\n(a) equitable access to land;\n(b) security of land rights;\n(c) sustainable and productive management of land resources;\n(d) transparent and cost effective administration of land;\n(e) sound conservation and protection of ecologically sensitive\nareas;\n42 Constitution of Kenya, 2010\n(f) elimination of gender discrimination in law, customs and\npractices related to land and property in land; and\n(g) encouragement of communities to settle land disputes\nthrough recognised local community initiatives consistent with\nthis Constitution.\n(2) These principles shall be implemented through a national land\npolicy developed and reviewed regularly by the national government\nand through legislation.',
# ...

# %%
sections = chapter_5_sections
##Define Q&A mapping for Chapter 5
qa_mapping = {
    "Principles of land": "Principles of land policy",
    "Classification of land": "Classification of land",
    "Public land": "Public land",
    "Community land": "Community land",
    "Private land": "Private land",
    "Landholding": "Landholding by non-citizens" ,
    "Regulation of land": "Regulation of land use and property",
    "Land Commission": "National Land Commission",
    "Legislation on land": "Legislation on land",
    "Obligations in respect of the environment": "Obligations in respect of the environment",
    "Enforcement of environmental rights": "Enforcement of environmental rights",
    "natural resource": "Agreements relating to natural resources",
    "Legislation relating to the environment": "Legislation relating to the environment"
}


##define the preprocess query function
def preprocess_query(query):
    return query.lower()  # Ensure case-insensitive matching

# Fix the answer_question_nlp function
def answer_question_nlp(query):
    # Preprocess the query
    preprocessed_query = preprocess_query(query)

    # Search for a matching key in QA_mapping
    for key, value in qa_mapping.items():
        if key.lower() in preprocessed_query:
            # Return the relevant section using the shorter section key (e.g., "Rights")
            return sections[key]  

    return "Sorry, I couldn't find an answer to your question."

# Example query
user_query = "discuss Enforcement of environmental rights constustution of kenya"
answer = answer_question_nlp(user_query)
print(answer)
# Out:
# Enforcement of environmental rights.
# 70. (1) If a person alleges that a right to a clean and healthy
# environment recognised and protected under Article 42 has been, is
# being or is likely to be, denied, violated, infringed or threatened, the
# person may apply to a court for redress in addition to any other legal
# remedies that are available in respect to the same matter.
# (2) On application under clause (1), the court may make any
# order, or give any directions, it considers appropriate—
# (a) to prevent, stop or discontinue any act or omission that is
# harmful to the environment;
# (b) to compel any public officer to take measures to prevent or
# discontinue any act or omission that is harmful to the
# environment; or
# (c) to provide compensation for any victim of a violation of the
# right to a clean and healthy environment.
# (3) For the purposes of this Article, an applicant does not have to
# demonstrate that any person has incurred loss or suffered injury.

# %% [markdown]
# ### Chapter 6
#
# ### Leadership and Intergrity
#
# #### Extracting chapter 6

# %%
# extracting the whole of chapter 4 which is located in page 48 to 51
chapter_6 = extract_specific_pages(pdf_path, 47, 51)
chapter_6
# Out:
# '48 Constitution of Kenya, 2010\n(b) is entered into on or after the effective date.\n(2) Parliament shall enact legislation providing for the classes of\ntransactions subject to ratification under clause (1).\nLegislation relating to the environment.\n72. Parliament shall enact legislation to give full effect to the\nprovisions of this Part.\nCHAPTER SIX—LEADERSHIP AND INTEGRITY\nResponsibilities of leadership.\n73. (1) Authority assigned to a State officer—\n(a) is a public trust to be exercised in a manner that—\n(i) is consistent with the purposes and objects of this\nConstitution;\n(ii) demonstrates respect for the people;\n(iii) brings honour to the nation and dignity to the office; and\n(iv) promotes public confidence in the integrity of the office;\nand\n(b) vests in the State officer the responsibility to serve the people,\nrather than the power to rule them.\n(2) The guiding principles of leadership and integrity include—\n(a) selection on the basis of personal integrity, c
# ...

# %% [markdown]
# ### The chapter 6 starts at page 48, which is shared by the end of chapter 5 and ends at page 51 and still the page is split into two thats is one partof the page is the start of chapter 7, we have to split this inorder to have just the info of chapter 6.

# %%
# remove chapter 3 and chapter 5 in pages 18 and 41 respectively, remain with chapter 4 alone
chapter_6_trimmed = chapter_6.split("CHAPTER SIX", 1)[1].split("CHAPTER SEVEN", 1)[0].strip()

print(chapter_6_trimmed)
# Out:
# —LEADERSHIP AND INTEGRITY
# Responsibilities of leadership.
# 73. (1) Authority assigned to a State officer—
# (a) is a public trust to be exercised in a manner that—
# (i) is consistent with the purposes and objects of this
# Constitution;
# (ii) demonstrates respect for the people;
# (iii) brings honour to the nation and dignity to the office; and
# (iv) promotes public confidence in the integrity of the office;
# and
# (b) vests in the State officer the responsibility to serve the people,
# rather than the power to rule them.
# (2) The guiding principles of leadership and integrity include—
# (a) selection on the basis of personal integrity, competence and
# suitability, or election in free and fair elections;
# (b) objectivity and impartiality in decision making, and in ensuring
# that decisions are not influenced by nepotism, favouritism,
# other improper motives or corrupt practices;
# (c) selfless service based solely on the public interest,
# demonstrated by—
# ...

# %% [markdown]
# ### Spliting chapter 6 to section

# %%
def split_chapter_6(chapter_text):
    # Split at key headings and strip extra whitespace
    sections = {
        "Responsibilities of leadership": [],
        "Oath": [],
        "Conduct": [],
        "Financial probity": [],
        "Restriction": [],
        "Citizenship": [],
        "ethics and anti-corruption": [],
        "Legislation on leadership": []
    }

    # Split by new lines to process line by line
    lines = chapter_text.splitlines()

    current_section = None

    for line in lines:
        stripped_line = line.strip()

        if stripped_line.startswith("Responsibilities of leadership"):
            current_section = "Responsibilities of leadership"
        elif stripped_line.startswith("Oath of office of State officers"):
            current_section = "Oath"
        elif stripped_line.startswith("Conduct of State officers"):
            current_section = "Conduct"
        elif stripped_line.startswith("Financial probity of State officers"):
            current_section = "Financial probity"
        elif stripped_line.startswith("Restriction on activities of State officers"):
            current_section = "Restriction"
        elif stripped_line.startswith("Citizenship and leadership"):
            current_section = "Citizenship"
        elif stripped_line.startswith("Legislation to establish the ethics and anti-corruption commission"):
            current_section = "ethics and anti-corruption"
        elif stripped_line.startswith("Legislation on leadership"):
            current_section = "Legislation on leadership"
        # Append line to the current section if it's set
        if current_section:
            sections[current_section].append(stripped_line)

    # Join each section into a single string
    for key in sections:
        sections[key] = "\n".join(sections[key])

    return sections

# Split the chapter into sections
chapter_6_sections = split_chapter_6(chapter_6_trimmed)

print("Financial probity Section:\n", chapter_6_sections['Financial probity'])
print("\nCitizenship Section:\n", chapter_6_sections['Citizenship'])
print("\nethics and anti-corruption Section:\n", chapter_6_sections['ethics and anti-corruption'])
# Out:
# Financial probity Section:
#  Financial probity of State officers.
# 76. (1) A gift or donation to a State officer on a public or official
# occasion is a gift or donation to the Republic and shall be delivered to
# the State unless exempted under an Act of Parliament.
# (2) A State officer shall not—
# (a) maintain a bank account outside Kenya except in accordance
# with an Act of Parliament; or
# (b) seek or accept a personal loan or benefit in circumstances
# that compromise the integrity of the State officer.
#
# Citizenship Section:
#  Citizenship and leadership.
# 78. (1) A person is not eligible for election or appointment to a
# State office unless the person is a citizen of Kenya.
# (2) A State officer or a member of the defence forces shall not
# hold dual citizenship.
# (3) Clauses (1) and (2) do not apply to—
# (a) judges and members of commissions; or
# (b) any person who has been made a citizen of another country
# ...

# %%
chapter_6_sections
# Out:
# {'Responsibilities of leadership': 'Responsibilities of leadership.\n73. (1) Authority assigned to a State officer—\n(a) is a public trust to be exercised in a manner that—\n(i) is consistent with the purposes and objects of this\nConstitution;\n(ii) demonstrates respect for the people;\n(iii) brings honour to the nation and dignity to the office; and\n(iv) promotes public confidence in the integrity of the office;\nand\n(b) vests in the State officer the responsibility to serve the people,\nrather than the power to rule them.\n(2) The guiding principles of leadership and integrity include—\n(a) selection on the basis of personal integrity, competence and\nsuitability, or election in free and fair elections;\n(b) objectivity and impartiality in decision making, and in ensuring\nthat decisions are not influenced by nepotism, favouritism,\nother improper motives or corrupt practices;\n(c) selfless service based solely on the public interest,\ndemonstrated by—\n(i) honesty in the execut
# ...

# %%
sections = chapter_6_sections
##Define Q&A mapping for Chapter 6
qa_mapping = {
        "Responsibilities of leadership": "Responsibilities of leadership",
        "Oath": "Oath of office of State officers",
        "Conduct": "Conduct of State officers",
        "Financial probity": "Financial probity of State officers",
        "Restriction": "Restriction on activities of State officers",
        "Citizenship": "Citizenship and leadership",
        "ethics and anti-corruption ": "Legislation to establish the ethics and anti-corruption commission",
        "Legislation on leadership": "Legislation on leadership"
}


#define the preprocess query function
def preprocess_query(query):
    return query.lower()  # Ensure case-insensitive matching

# Fix the answer_question_nlp function
def answer_question_nlp(query):
    # Preprocess the query
    preprocessed_query = preprocess_query(query)

    # Search for a matching key in QA_mapping
    for key, value in qa_mapping.items():
        if key.lower() in preprocessed_query:
            # Return the relevant section using the shorter section key (e.g., "Rights")
            return sections[key]  

    return "Sorry, I couldn't find an answer to your question."

# Example query
user_query = "what can you say is Citizenship"
answer = answer_question_nlp(user_query)
print(answer)
# Out:
# Citizenship and leadership.
# 78. (1) A person is not eligible for election or appointment to a
# State office unless the person is a citizen of Kenya.
# (2) A State officer or a member of the defence forces shall not
# hold dual citizenship.
# (3) Clauses (1) and (2) do not apply to—
# (a) judges and members of commissions; or
# (b) any person who has been made a citizen of another country
# by operation of that country’s law, without ability to opt out.
# Legislation to establish the ethics and anti-corruption
# commission.
# 79. Parliament shall enact legislation to establish an independent
# ethics and anti-corruption commission, which shall be and have the
# status and powers of a commission under Chapter Fifteen, for
# purposes of ensuring compliance with, and enforcement of, the
# provisions of this Chapter.

# %% [markdown]
# ### NLP
#
# ### Chapter 4

# %%
import logging
from spellchecker import SpellChecker
from fuzzywuzzy import fuzz

# %% [markdown]
# ### Debugging code

# %%
# Define synonym mapping
synonyms = {
    "Rights and fundamental freedoms": ["bill of rights", "fundamental freedoms", "human rights", "basic rights", "constitutional rights"],
    "Application of bill": ["application of rights", "bill of rights enforcement", "enforcement of freedoms"],
    "Implementation of rights": ["realization of freedoms", "promotion of rights", "protection of liberties", "observance of fundamental rights"],
    "courts": ["judicial power", "court jurisdiction", "enforcement of rights", "judicial review"],
    "Limitation of rights": ["restriction of freedoms", "reasonable limitations", "justifiable constraints", "rights boundaries"],
    "Fundamental rights": ["absolute rights", "inalienable freedoms", "non-negotiable rights", "core human rights"],
    "life": ["life", "existence", "entitlement to life", "right to exist"],
    "Equality": ["equal treatment", "non-discrimination", "fairness", "equality of opportunity"],
    "dignity": ["fundamental worth", "intrinsic respect", "inherent value", "personal honor"],
    "security": ["liberty", "personal safety", "protection from harm", "security of the individual"],
    "Slavery": ["bondage", "forced servitude", "involuntary labor", "coerced work"],
    "Privacy": ["confidentiality", "personal space", "right to seclusion", "protection of personal information"],
    "conscience": ["liberty of thought", "religious freedom", "belief autonomy", "freedom of opinion"],
    "expression": ["communication", "right to speak", "artistic freedom", "expression of ideas"],
    "media": ["media independence", "journalistic freedom", "press autonomy", "right to information"],
    "information": ["right to knowledge", "information availability", "transparency", "access to data"],
    "association": ["right to gather", "group formation", "collective action", "association rights"],
    "Assembly, Demonstration, Picketing, and Petition": ["right to protest", "peaceful assembly", "public demonstration", "petitioning rights"],
    "Political": ["electoral rights", "civic participation", "political engagement", "voting rights"],
    "movement": ["mobility rights", "right to travel", "residential freedom", "movement liberties"],
    "Property": ["property rights", "ownership protection", "assets security", "right to possessions"],
    "Labour": ["employment rights", "worker protections", "fair labor practices", "collective bargaining"],
    "Environment": ["environmental rights", "sustainable surroundings", "right to a healthy environment", "protection of natural resources"],
    "Economic": ["right to health", "standard of living", "social welfare", "economic security"],
    "Language": ["cultural rights", "linguistic freedoms", "cultural expression", "heritage preservation"],
    "Family": ["family rights", "natural family unit", "societal foundation", "parental rights"],
    "Consumer": ["rights of consumers", "consumer protections", "entitlements for buyers", "purchaser rights"],
    "administrative": ["just administrative processes", "equitable administrative decisions", "lawful administrative action"],
    "justice": ["right to legal recourse", "legal access", "justice availability", "access to legal remedies"],
    "arrested": ["arrestee rights", "rights of detainees", "entitlements of arrested individuals", "protections for arrested persons"],
    "hearing": ["right to a fair trial", "equitable hearing", "just legal proceedings", "right to impartial adjudication"],
    "custody": ["entitlements of detainees", "protections for persons in custody", "fundamental freedoms for prisoners"],
    "Children": ["child rights", "children's entitlements", "rights of minors", "protections for children"],
    "disabilities": ["disability rights", "protections for disabled individuals", "rights of differently-abled persons"],
    "Youth": ["youth rights", "entitlements for young people", "protections for youth", "rights of adolescents"],
    "marginalised": ["minority rights", "rights of marginalized communities", "protections for marginalized populations"],
    "Older": ["elderly rights", "entitlements for older persons", "protections for seniors", "rights of the aged"],
    "emergency": ["emergency declaration", "crisis state", "public emergency", "emergency status"],
    "National Human Rights": ["National Human Rights Commission", "Human Rights and Equality Body", "Kenya Human Rights Authority"]
}

# QA mapping
qa_mapping = {
    "Rights and fundamental freedoms": ("Rights and fundamental freedoms"),
    "Application of bill": ("Application of bill"),
    "Implementation of rights": ("Implementation of rights"),
    "courts": ("courts"),
    "Limitation of rights": ("Limitation of rights"),
    "Fundamental rights": ("Fundamental rights"),
    "life": ("life"),
    "Equality": ("Equality"),
    "dignity": ("dignity"),
    "security": ("security"),
    "Slavery": ("Slavery"),
    "Privacy": ("Privacy"),
    "conscience": ("conscience"),
    "expression": ("expression"),
    "media": ("media"),
    "information": ("information"),
    "association": ("association"),
    "Assembly, Demonstration, Picketing, and Petition": ("Assembly, Demonstration, Picketing, and Petition"),
    "Political": ("Political"),
    "movement": ("movement"),
    "property": ("property"),
    "Labour": ("Labour"),
    "Environment": (""),
    "Economic": ("Economic"),
    "Language": ("Language"),
    "Family": ("Family"),
    "Consumer": ("Consumer"),
    "administrative": ("administrative"),
    "justice": ("justice"),
    "arrested": ("arrested"),
    "hearing": ("hearing"),
    "custody": ("custody"),
    "Children": ("Children"),
    "disabilities": ("disabilities"),
    "Youth": ("Youth"),
    "marginalised": ("marginalised"),
    "Older": ("Older"),
    "emergency": ("emergency"),
    "National Human Rights": ("National Human Rights")
}

# Preprocess the query
def preprocess_query(query):
    doc = nlp(query)
    tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(tokens)

# Function to correct the spelling
def correct_spelling(processed_query):
    spell = SpellChecker()
    words = processed_query.split()
    # Find misspelled words
    misspelled_words = spell.unknown(words)


    corrected_words = []
    for word in words:
        # Correct the word if it's misspelled
        if word in misspelled_words:
            corrected_word = spell.correction(word) # Get the most likely correction
            corrected_words.append(corrected_word)
        else:
            corrected_words.append(word)

    # Reconstruct the initial sentence
    corrected_input = " ".join(corrected_words)

    return corrected_input

            

# Match with fuzzy matching and synonym support
def match_with_synonyms(query, qa_mapping, synonyms):
    processed_query = preprocess_query(query)
    print(f"Processed Query: {processed_query}")  # Debugging line

    # Correct spelling in the processed query
    corrected_query = correct_spelling(processed_query)
    print(f"Corrected Query: {corrected_query}")  # Debugging line


    for key, value in qa_mapping.items():
        print(f"Checking key: {key}, value: {value}")  # Debugging line
        for synonym in synonyms.get(key, [key]):
            print(f"Trying synonym: {synonym}")  # Debugging line
            if synonym in corrected_query:
                print(f"Match found with synonym: {synonym}")  # Debugging line
                return value  # Only return section value of the key
            
            # Check for fuzzy matching with the synonym
            if fuzz.ratio(synonym, corrected_query) > 70:
                print(f"Fuzzy match found with synonym: {synonym}")  # Debugging line
                return value  # Return the key for the section
    
    print("No match found")  # Debugging line if no match is found
    return None

# Answer function with synonym and fuzzy matching
def answer_question_nlp(query, sections, qa_mapping, synonyms):
    section_key = match_with_synonyms(query, qa_mapping, synonyms)
    
    if section_key:
        # Retrieve the relevant section from the specified chapter
        return sections.get(section_key, "Section not found.")
    
    return "Sorry, I couldn't find an answer to your question."

# %% [markdown]
# ### Precise code

# %%
# Define synonym mapping
synonyms = {
    "fundamental freedoms": ["bill of rights", "fundamental freedoms", "human rights", "basic rights", "constitutional rights"],
    "Application of bill": ["application of rights", "bill of rights enforcement", "enforcement of freedoms"],
    "Implementation of rights": ["realization of freedoms", "promotion of rights", "protection of liberties", "observance of fundamental rights"],
    "courts": ["judicial power", "court jurisdiction", "enforcement of rights", "judicial review"],
    "Limitation of rights": ["restriction of freedoms", "reasonable limitations", "justifiable constraints", "rights boundaries"],
    "Fundamental rights": ["absolute rights", "inalienable freedoms", "non-negotiable rights", "core human rights"],
    "life": ["life", "existence", "entitlement to life", "right to exist"],
    "Equality": ["equal treatment", "non-discrimination", "fairness", "equality of opportunity"],
    "dignity": ["fundamental worth", "intrinsic respect", "inherent value", "personal honor"],
    "security": ["liberty", "personal safety", "protection from harm", "security of the individual"],
    "Slavery": ["bondage", "forced servitude", "involuntary labor", "coerced work"],
    "Privacy": ["confidentiality", "personal space", "right to seclusion", "protection of personal information"],
    "conscience": ["liberty of thought", "religious freedom", "belief autonomy", "freedom of opinion"],
    "expression": ["communication", "right to speak", "artistic freedom", "expression of ideas"],
    "media": ["media independence", "journalistic freedom", "press autonomy", "right to information"],
    "information": ["right to knowledge", "information availability", "transparency", "access to data"],
    "association": ["right to gather", "group formation", "collective action", "association rights"],
    "Assembly, Demonstration, Picketing, and Petition": ["right to protest", "peaceful assembly", "public demonstration", "petitioning rights"],
    "Political": ["electoral rights", "civic participation", "political engagement", "voting rights"],
    "movement": ["mobility rights", "right to travel", "residential freedom", "movement liberties"],
    "property": ["property rights", "ownership protection", "assets security", "right to possessions"],
    "Labour": ["employment rights", "worker protections", "fair labor practices", "collective bargaining"],
    "Environment": ["environmental rights", "sustainable surroundings", "right to a healthy environment", "protection of natural resources"],
    "Economic": ["right to health", "standard of living", "social welfare", "economic security"],
    "Language": ["cultural rights", "linguistic freedoms", "cultural expression", "heritage preservation"],
    "Family": ["family rights", "natural family unit", "societal foundation", "parental rights"],
    "Consumer": ["rights of consumers", "consumer protections", "entitlements for buyers", "purchaser rights"],
    "administrative": ["just administrative processes", "equitable administrative decisions", "lawful administrative action"],
    "justice": ["right to legal recourse", "legal access", "justice availability", "access to legal remedies"],
    "arrested": ["arrestee rights", "rights of detainees", "entitlements of arrested individuals", "protections for arrested persons"],
    "hearing": ["right to a fair trial", "equitable hearing", "just legal proceedings", "right to impartial adjudication"],
    "custody": ["entitlements of detainees", "protections for persons in custody", "fundamental freedoms for prisoners"],
    "Interpretation of this Part": ["explanation of this section", "clarification of this segment", "understanding of this chapter"],
    "Children": ["child rights", "children's entitlements", "rights of minors", "protections for children"],
    "disabilities": ["disability rights", "protections for disabled individuals", "rights of differently-abled persons"],
    "Youth": ["youth rights", "entitlements for young people", "protections for youth", "rights of adolescents"],
    "marginalised": ["minority rights", "rights of marginalized communities", "protections for marginalized populations"],
    "Older": ["elderly rights", "entitlements for older persons", "protections for seniors", "rights of the aged"],
    "emergency": ["emergency declaration", "crisis state", "public emergency", "emergency status"],
    "National Human Rights": ["National Human Rights Commission", "Human Rights and Equality Body", "Kenya Human Rights Authority"],
}

# QA mapping
qa_mapping = {
    "fundamental freedoms": ("Rights and fundamental freedoms"),
    "Application of bill": ("Application of bill"),
    "Implementation of rights": ("Implementation of rights"),
    "courts": ("courts"),
    "Limitation of rights": ("Limitation of rights"),
    "Fundamental rights": ("Fundamental rights"),
    "life": ("life"),
    "Equality": ("Equality"),
    "dignity": ("dignity"),
    "security": ("security"),
    "Slavery": ("Slavery"),
    "Privacy": ("Privacy"),
    "conscience": ("conscience"),
    "expression": ("expression"),
    "media": ("media"),
    "information": ("information"),
    "association": ("association"),
    "Assembly, Demonstration, Picketing, and Petition": ("Assembly, Demonstration, Picketing, and Petition"),
    "Political": ("Political"),
    "movement": ("movement"),
    "property": ("property"),
    "Labour": ("Labour"),
    "Environment": (""),
    "Economic": ("Economic"),
    "Language": ("Language"),
    "Family": ("Family"),
    "Consumer": ("Consumer"),
    "administrative": ("administrative"),
    "justice": ("justice"),
    "arrested": ("arrested"),
    "hearing": ("hearing"),
    "custody": ("custody"),
    "Interpretation of this Part": ("Interpretation of this Part"),
    "Children": ("Children"),
    "disabilities": ("disabilities"),
    "Youth": ("Youth"),
    "marginalised": ("marginalised"),
    "Older": ("Older"),
    "emergency": ("emergency"),
    "National Human Rights": ("National Human Rights")
}

# Preprocess the query
def preprocess_query(query):
    doc = nlp(query)
    tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(tokens)

# Function to correct the spelling
def correct_spelling(processed_query):
    spell = SpellChecker()
    words = processed_query.split()
    # Find misspelled words
    misspelled_words = spell.unknown(words)


    corrected_words = []
    for word in words:
        # Correct the word if it's misspelled
        if word in misspelled_words:
            corrected_word = spell.correction(word) # Get the most likely correction
            corrected_words.append(corrected_word)
        else:
            corrected_words.append(word)

    # Reconstruct the initial sentence
    corrected_input = " ".join(corrected_words)

    return corrected_input

            

# Match with fuzzy matching and synonym support
def match_with_synonyms(query, qa_mapping, synonyms):
    processed_query = preprocess_query(query)

    # Correct spelling in the processed query
    corrected_query = correct_spelling(processed_query)


    for key, value in qa_mapping.items():
        for synonym in synonyms.get(key, [key]):
            if synonym in corrected_query:
                return value  # Only return section value of the key
            
            # Check for fuzzy matching with the synonym
            if fuzz.ratio(synonym, corrected_query) > 70:
                print(f"Fuzzy match found with synonym: {synonym}")  # Debugging line
                return value  # Return the key for the section
    
    print("No match found")
    return None

# Answer function with synonym and fuzzy matching
def answer_question_nlp(query, sections, qa_mapping, synonyms):
    section_key = match_with_synonyms(query, qa_mapping, synonyms)
    
    if section_key:
        # Retrieve the relevant section from the specified chapter
        return sections.get(section_key, "Section not found.")
    
    return "Sorry, I couldn't find an answer to your question."

# %%
sections = chapter_4_sections

# %%
user_query = "What explanation of this section?"
answer = answer_question_nlp(user_query, sections, qa_mapping, synonyms)
print(answer)
# Out:
# Fuzzy match found with synonym: explanation of this section
# Interpretation of this Part.
# 52. (1) This Part elaborates certain rights to ensure greater
# certainty as to the application of those rights and fundamental
# freedoms to certain groups of persons.
# (2) This Part shall not be construed as limiting or qualifying any
# right.

# %%
user_query = "What employment rights?"
answer = answer_question_nlp(user_query, sections, qa_mapping, synonyms)
print(answer)
# Out:
# Fuzzy match found with synonym: employment rights
# Labour relations.
# 41. (1) Every person has the right to fair labour practices.
# (2) Every worker has the right—
# (a) to fair remuneration;
# (b) to reasonable working conditions;
# (c) to form, join or participate in the activities and programmes of
# a trade union; and
# (d) to go on strike.
# (3) Every employer has the right—
# (e) to form and join an employers organisation; and
# (f) to participate in the activities and programmes of an employers
# organisation.
# (4) Every trade union and every employers’ organisation has the
# right—
# (a) to determine its own administration, programmes and
# activities;
# (b) to organise; and
# (c) to form and join a federation.
# (5) Every trade union, employers’ organisation and employer has
# the right to engage in collective bargaining.
# Constitution of Kenya, 2010 31

# %% [markdown]
# ### Chapter 5

# %% [markdown]
# ###  debugging code

# %%
# Define synonym mapping
synonyms = {
    "principles of land": ["principles of land policy", "land management principles", "land policy guidelines", "equitable land administration"],
    "classification of land": ["classification of land", "land categories", "types of land ownership", "land designation"],
    "public land": ["public land", "government-owned land", "state property", "land for public use", "national land assets", "public landholding"],
    "community land": ["community land", "ethnic group land", "cultural landholdings", "land for community use", "community owned land"],
    "private land": ["private land", "individual landholding", "personal property", "leased land", "freehold land", "privately owned land"],
    "Landholding" : ["non-citizen ownership", "foreign lease", "alien land tenure", "leasehold limitation", "property by non-citizens"],
    "Regulation of land" : ["land governance", "land use policy", "property regulation", "land planning control", "land oversight"],
    "Land Commission" : ["land authority", "land management board", "public land commission", "land governance body", "land policy agency"],
    "Legislation on land" : ["land laws", "land legislation", "property laws", "land-use regulation", "statutory land provisions", "land act"],
    "Obligations in respect of the environment" : ["environmental duty", "ecological obligations", "biodiversity duty", "conservation mandate"],
    "Enforcement of environmental rights" : ["environmental justice", "ecological redress", "sustainability enforcement", "ecosystem law enforcement"],
    "natural resource" : ["natural resource contracts", "resource exploitation deals", "resource use agreements", "environmental concessions"],
    "Legislation relating to the environment" : ["environmental laws", "ecological legislation", "natural resource statutes", "green policy enactments"]
}

# QA mapping
qa_mapping = {
    "principles of land": ("principles of land"),
    "classification of land": ("classification of land"),
    "public land": ("public land"),
    "community land": ("community land"),
    "private land": ("private land"),
    "Landholding": ("Landholding"),
    "Regulation of land": ("Regulation of land"),
    "Land Commission": ("Land Commission"),
    "Legislation on land": ("Legislation on land"),
    "Obligations in respect of the environment": ("Obligations in respect of the environment"),
    "Enforcement of environmental rights": ("Enforcement of environmental rights"),
    "natural resource": ("natural resource"),
    "Legislation relating to the environment": ("Legislation relating to the environment")
}

# Preprocess the query
def preprocess_query(query):
    doc = nlp(query)
    tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(tokens)

# Function to correct the spelling
def correct_spelling(processed_query):
    spell = SpellChecker()
    words = processed_query.split()
    # Find misspelled words
    misspelled_words = spell.unknown(words)


    corrected_words = []
    for word in words:
        # Correct the word if it's misspelled
        if word in misspelled_words:
            corrected_word = spell.correction(word) # Get the most likely correction
            corrected_words.append(corrected_word)
        else:
            corrected_words.append(word)

    # Reconstruct the initial sentence
    corrected_input = " ".join(corrected_words)

    return corrected_input

            

# Match with fuzzy matching and synonym support
def match_with_synonyms(query, qa_mapping, synonyms):
    processed_query = preprocess_query(query)
    print(f"Processed Query: {processed_query}")  # Debugging line

    # Correct spelling in the processed query
    corrected_query = correct_spelling(processed_query)
    print(f"Corrected Query: {corrected_query}")  # Debugging line


    for key, value in qa_mapping.items():
        print(f"Checking key: {key}, value: {value}")  # Debugging line
        for synonym in synonyms.get(key, [key]):
            print(f"Trying synonym: {synonym}")  # Debugging line
            if synonym in corrected_query:
                print(f"Match found with synonym: {synonym}")  # Debugging line
                return value  # Only return section value of the key
            
            # Check for fuzzy matching with the synonym
            if fuzz.ratio(synonym, corrected_query) > 70:
                print(f"Fuzzy match found with synonym: {synonym}")  # Debugging line
                return value  # Return the key for the section
    
    print("No match found")  # Debugging line if no match is found
    return None

# Answer function with synonym and fuzzy matching
def answer_question_nlp(query, sections, qa_mapping, synonyms):
    section_key = match_with_synonyms(query, qa_mapping, synonyms)
    
    if section_key:
        # Retrieve the relevant section from the specified chapter
        return sections.get(section_key, "Section not found.")
    
    return "Sorry, I couldn't find an answer to your question."

# %% [markdown]
# ### Precise code

# %%
# Define synonym mapping
synonyms = {
    "Principles of land": ["principles of land policy", "land management principles", "land policy guidelines", "equitable land administration"],
    "Classification of land": ["classification of land", "land categories", "types of land ownership", "land designation"],
    "Public land": ["public land", "government-owned land", "state property", "land for public use", "national land assets", "public landholding"],
    "Community land": ["community land", "ethnic group land", "cultural landholdings", "land for community use", "community owned land"],
    "Private land": ["private land", "individual landholding", "personal property", "leased land", "freehold land", "privately owned land"],
    "Landholding" : ["non-citizen ownership", "foreign lease", "alien land tenure", "leasehold limitation", "property by non-citizens"],
    "Regulation of land" : ["land governance", "land use policy", "property regulation", "land planning control", "land oversight"],
    "land Commission" : ["land authority", "land management board", "public land commission", "land governance body", "land policy agency"],
    "Legislation on land" : ["land laws", "land legislation", "property laws", "land-use regulation", "statutory land provisions", "land act"],
    "Obligations in respect of the environment" : ["environmental duty", "ecological obligations", "biodiversity duty", "conservation mandate"],
    "Enforcement of environmental rights" : ["environmental justice", "ecological redress", "sustainability enforcement", "ecosystem law enforcement"],
    "natural resource" : ["natural resource contracts", "resource exploitation deals", "resource use agreements", "environmental concessions"],
    "Legislation relating to the environment" : ["environmental laws", "ecological legislation", "natural resource statutes", "green policy enactments"]
}

# QA mapping
qa_mapping = {
    "Principles of land": ("Principles of land"),
    "Classification of land": ("Classification of land"),
    "Public land": ("Public land"),
    "Community land": ("Community land"),
    "Private land": ("Private land"),
    "Landholding": ("Landholding"),
    "Regulation of land": ("Regulation of land"),
    "land Commission": ("land Commission"),
    "Legislation on land": ("Legislation on land"),
    "Obligations in respect of the environment": ("Obligations in respect of the environment"),
    "Enforcement of environmental rights": ("Enforcement of environmental rights"),
    "natural resource": ("natural resource"),
    "Legislation relating to the environment": ("Legislation relating to the environment"),
    

}

# Preprocess the query
def preprocess_query(query):
    doc = nlp(query)
    tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(tokens)

# Function to correct the spelling
def correct_spelling(processed_query):
    spell = SpellChecker()
    words = processed_query.split()
    # Find misspelled words
    misspelled_words = spell.unknown(words)


    corrected_words = []
    for word in words:
        # Correct the word if it's misspelled
        if word in misspelled_words:
            corrected_word = spell.correction(word) # Get the most likely correction
            corrected_words.append(corrected_word)
        else:
            corrected_words.append(word)

    # Reconstruct the initial sentence
    corrected_input = " ".join(corrected_words)

    return corrected_input

            

# Match with fuzzy matching and synonym support
def match_with_synonyms(query, qa_mapping, synonyms):
    processed_query = preprocess_query(query)

    # Correct spelling in the processed query
    corrected_query = correct_spelling(processed_query)


    for key, value in qa_mapping.items():
        for synonym in synonyms.get(key, [key]):
            if synonym in corrected_query:
                return value  # Only return section value of the key
            
            # Check for fuzzy matching with the synonym
            if fuzz.ratio(synonym, corrected_query) > 70:
                print(f"Fuzzy match found with synonym: {synonym}")  # Debugging line
                return value  # Return the key for the section
    
    print("No match found")
    return None

# Answer function with synonym and fuzzy matching
def answer_question_nlp(query, sections, qa_mapping, synonyms):
    section_key = match_with_synonyms(query, qa_mapping, synonyms)
    
    if section_key:
        # Retrieve the relevant section from the specified chapter
        return sections.get(section_key, "Section not found.")
    
    return "Sorry, I couldn't find an answer to your question."

# %%
sections = chapter_5_sections

# %%
user_query = "What is natural resource contractsoi?"
answer = answer_question_nlp(user_query, sections, qa_mapping, synonyms)
print(answer)
# Out:
# Agreements relating to natural resource.
# 71. (1) A transaction is subject to ratification by Parliament if it—
# (a) involves the grant of a right or concession by or on behalf of
# any person, including the national government, to another
# person for the exploitation of any natural resource of Kenya;
# and
# 48 Constitution of Kenya, 2010
# (b) is entered into on or after the effective date.
# (2) Parliament shall enact legislation providing for the classes of
# transactions subject to ratification under clause (1).

# %%
user_query = "What  is foreign lease?"
answer = answer_question_nlp(user_query, sections, qa_mapping, synonyms)
print(answer)
# Out:
# Landholding by non-citizens.
# 65. (1) A person who is not a citizen may hold land on the basis
# of leasehold tenure only, and any such lease, however granted, shall
# not exceed ninety-nine years.
# (2) If a provision of any agreement, deed, conveyance or
# document of whatever nature purports to confer on a person who is
# not a citizen an interest in land greater than a ninety-nine year lease,
# the provision shall be regarded as conferring on the person a ninety-
# nine year leasehold interest, and no more.
# (3) For purposes of this Article—
# (a) a body corporate shall be regarded as a citizen only if the
# body corporate is wholly owned by one or more citizens; and
# Constitution of Kenya, 2010 45
# (b) property held in trust shall be regarded as being held by a
# citizen only if all of the beneficial interest of the trust is held by
# persons who are citizens.
# (4) Parliament may enact legislation to make further provision for
# the operation of this Article.

# %% [markdown]
# ### NLP
#
# ### Chapter 6

# %%
# Define synonym mapping
synonyms = {
    "Responsibilities of leadership": ["Leadership obligations", "Duties of leadership", "Leadership responsibilities"],
    "Oath": ["Swearing-in of State officers", "State officer oath", "State office affirmation"],
    "Conduct": ["Behavior of State officers", "State officer conduct", "Ethics for State officers"],
    "Financial probity": ["State officer financial integrity", "Monetary probity of officers", "Fiscal responsibility of State officers"],
    "Restriction": ["Limitations on State officers", "State officer restrictions", "Employment restrictions for officers"],
    "Citizenship": ["Citizenship eligibility for leaders", "Leadership and nationality", "State office citizenship requirements"],
    "ethics and anti-corruption": ["Anti-corruption commission laws", "Establishing ethics commission", "Laws for ethics enforcement"],
    "Legislation on leadership": ["Leadership laws", "Regulations on leadership", "Legislation governing leadership"]
}

# QA mapping
qa_mapping = {
    "Responsibilities of leadership": ("Responsibilities of leadership"),
    "Oath": ("Oath"),
    "Conduct": ("Conduct"),
    "Financial probity": ("Financial probity"),
    "Restriction": ("Restriction"),
    "Citizenship": ("Citizenship"),
    "ethics and anti-corruption": ("ethics and anti-corruption"),
    "Legislation on leadership": ("Legislation on leadership")
}

# Preprocess the query
def preprocess_query(query):
    doc = nlp(query)
    tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(tokens)

# Function to correct the spelling
def correct_spelling(processed_query):
    spell = SpellChecker()
    words = processed_query.split()
    # Find misspelled words
    misspelled_words = spell.unknown(words)


    corrected_words = []
    for word in words:
        # Correct the word if it's misspelled
        if word in misspelled_words:
            corrected_word = spell.correction(word) # Get the most likely correction
            corrected_words.append(corrected_word)
        else:
            corrected_words.append(word)

    # Reconstruct the initial sentence
    corrected_input = " ".join(corrected_words)

    return corrected_input

            

# Match with fuzzy matching and synonym support
def match_with_synonyms(query, qa_mapping, synonyms):
    processed_query = preprocess_query(query)
    print(f"Processed Query: {processed_query}")  # Debugging line

    # Correct spelling in the processed query
    corrected_query = correct_spelling(processed_query)
    print(f"Corrected Query: {corrected_query}")  # Debugging line


    for key, value in qa_mapping.items():
        print(f"Checking key: {key}, value: {value}")  # Debugging line
        for synonym in synonyms.get(key, [key]):
            print(f"Trying synonym: {synonym}")  # Debugging line
            if synonym in corrected_query:
                print(f"Match found with synonym: {synonym}")  # Debugging line
                return value  # Only return section value of the key
            
            # Check for fuzzy matching with the synonym
            if fuzz.ratio(synonym, corrected_query) > 70:
                print(f"Fuzzy match found with synonym: {synonym}")  # Debugging line
                return value  # Return the key for the section
    
    print("No match found")  # Debugging line if no match is found
    return None

# Answer function with synonym and fuzzy matching
def answer_question_nlp(query, sections, qa_mapping, synonyms):
    section_key = match_with_synonyms(query, qa_mapping, synonyms)
    
    if section_key:
        # Retrieve the relevant section from the specified chapter
        return sections.get(section_key, "Section not found.")
    
    return "Sorry, I couldn't find an answer to your question."

# %%
# Define synonym mapping
synonyms = {
    "Responsibilities of leadership": ["Leadership obligations", "Duties of leadership", "Leadership responsibilities"],
    "Oath": ["Swearing-in of State officers", "State officer oath", "State office affirmation"],
    "Conduct": ["Behavior of State officers", "State officer conduct", "Ethics for State officers"],
    "Financial probity": ["State officer financial integrity", "Monetary probity of officers", "Fiscal responsibility of State officers"],
    "Restriction": ["Limitations on State officers", "State officer restrictions", "Employment restrictions for officers"],
    "Citizenship": ["Citizenship eligibility for leaders", "Leadership and nationality", "State office citizenship requirements"],
    "ethics and anti-corruption": ["Anti-corruption commission laws", "Establishing ethics commission", "Laws for ethics enforcement"],
    "Legislation on leadership": ["Leadership laws", "Regulations on leadership", "Legislation governing leadership"]
}

# QA mapping
qa_mapping = {
    "Responsibilities of leadership": ("Responsibilities of leadership"),
    "Oath": ("Oath"),
    "Conduct": ("Conduct"),
    "Financial probity": ("Financial probity"),
    "Restriction": ("Restriction"),
    "Citizenship": ("Citizenship"),
    "ethics and anti-corruption": ("ethics and anti-corruption"),
    "Legislation on leadership": ("Legislation on leadership")
}

# Preprocess the query
def preprocess_query(query):
    doc = nlp(query)
    tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(tokens)

# Function to correct the spelling
def correct_spelling(processed_query):
    spell = SpellChecker()
    words = processed_query.split()
    # Find misspelled words
    misspelled_words = spell.unknown(words)


    corrected_words = []
    for word in words:
        # Correct the word if it's misspelled
        if word in misspelled_words:
            corrected_word = spell.correction(word) # Get the most likely correction
            corrected_words.append(corrected_word)
        else:
            corrected_words.append(word)

    # Reconstruct the initial sentence
    corrected_input = " ".join(corrected_words)

    return corrected_input

            

# Match with fuzzy matching and synonym support
def match_with_synonyms(query, qa_mapping, synonyms):
    processed_query = preprocess_query(query)

    # Correct spelling in the processed query
    corrected_query = correct_spelling(processed_query)


    for key, value in qa_mapping.items():
        for synonym in synonyms.get(key, [key]):
            if synonym in corrected_query:
                return value  # Only return section value of the key
            
            # Check for fuzzy matching with the synonym
            if fuzz.ratio(synonym, corrected_query) > 70:
                print(f"Fuzzy match found with synonym: {synonym}")  # Debugging line
                return value  # Return the key for the section
    
    print("No match found")
    return None

# Answer function with synonym and fuzzy matching
def answer_question_nlp(query, sections, qa_mapping, synonyms):
    section_key = match_with_synonyms(query, qa_mapping, synonyms)
    
    if section_key:
        # Retrieve the relevant section from the specified chapter
        return sections.get(section_key, "Section not found.")
    
    return "Sorry, I couldn't find an answer to your question."

# %%
sections = chapter_6_sections

# %%
user_query = "What is State officer financial integrity?"
answer = answer_question_nlp(user_query, sections, qa_mapping, synonyms)
print(answer)
# Out:
# Fuzzy match found with synonym: State officer financial integrity
# Financial probity of State officers.
# 76. (1) A gift or donation to a State officer on a public or official
# occasion is a gift or donation to the Republic and shall be delivered to
# the State unless exempted under an Act of Parliament.
# (2) A State officer shall not—
# (a) maintain a bank account outside Kenya except in accordance
# with an Act of Parliament; or
# (b) seek or accept a personal loan or benefit in circumstances
# that compromise the integrity of the State officer.

# %%
user_query = "What is Ethics for State officers?"
answer = answer_question_nlp(user_query, sections, qa_mapping, synonyms)
print(answer)
# Out:
# Fuzzy match found with synonym: Ethics for State officers
# Conduct of State officers.
# 75. (1) A State officer shall behave, whether in public and official
# life, in private life, or in association with other persons, in a manner
# that avoids—
# (a) any conflict between personal interests and public or official
# duties;
# (b) compromising any public or official interest in favour of a
# personal interest; or
# (c) demeaning the office the officer holds.
# (2) A person who contravenes clause (1), or Article 76, 77 or 78
# (2)—
# (a) shall be subject to the applicable disciplinary procedure for
# the relevant office; and
# (b) may, in accordance with the disciplinary procedure referred to
# in paragraph (a), be dismissed or otherwise removed from
# office.
# (3) A person who has been dismissed or otherwise removed from
# office for a contravention of the provisions specified in clause (2) is
# disqualified from holding any other State office.

# %% [markdown]
# ### Combining chapters into a single dictionary

# %%
combined_sections = combined_sections = {**chapter_4_sections, **chapter_5_sections, **chapter_6_sections}
# Print the keys of the dictionary
combined_sections.keys()
# Out:
# dict_keys(['fundamental freedoms', 'Application of Bill', 'Implementation of rights', 'Enforcement of Bill', 'courts', 'Limitation of rights', 'Fundamental Rights', 'life', 'Equality', 'dignity', 'security', 'Slavery', 'Privacy', 'conscience', 'expression', 'media', 'information', 'association', 'Assembly, demonstration, picketing and petition', 'Political', 'movement', 'property', 'Labour', 'Environment', 'Economic', 'Language', 'Family', 'Consumer', 'administrative', 'justice', 'arrested', 'hearing', 'custody', 'Interpretation of this Part', 'Children', 'disabilities', 'Youth', 'marginalised', 'Older', 'emergency', 'National Human Rights', 'Principles of land', 'Classification of land', 'Public land', 'Community land', 'Private land', 'Landholding', 'Regulation of land', 'Land Commission', 'Legislation on land', 'Obligations in respect of the environment', 'Enforcement of environmental rights', 'natural resource', 'Legislation relating to the environment', 'Responsibilities of lead
# ...

# %%
# Load the spacy model
nlp = spacy.load("en_core_web_sm")

# Configure logging
logging.basicConfig(
    level=logging.DEBUG,  # Set the logging level
    format='%(asctime)s - %(levelname)s - %(message)s',  # Log message format
)

# Define synonym mapping
synonyms = {
    "fundamental freedoms": ["fundamental freedoms", "human rights", "basic rights", "constitutional rights"],
    "Application of bill": ["application of rights", "bill of rights enforcement", "enforcement of freedoms"],
    "Implementation of rights": ["realization of freedoms", "promotion of rights", "protection of liberties", "observance of fundamental rights"],
    "courts": ["judicial power", "court jurisdiction", "enforcement of rights", "judicial review"],
    "Limitation of rights": ["restriction of freedoms", "reasonable limitations", "justifiable constraints", "rights boundaries"],
    "Fundamental rights": ["absolute rights", "inalienable freedoms", "non-negotiable rights", "core human rights"],
    "life": ["life", "existence", "entitlement to life", "right to exist"],
    "Equality": ["equal treatment", "non-discrimination", "fairness", "equality of opportunity"],
    "dignity": ["fundamental worth", "intrinsic respect", "inherent value", "personal honor"],
    "security": ["liberty", "personal safety", "protection from harm", "security of the individual"],
    "Slavery": ["bondage", "forced servitude", "involuntary labor", "coerced work"],
    "Privacy": ["confidentiality", "personal space", "right to seclusion", "protection of personal information"],
    "conscience": ["liberty of thought", "religious freedom", "belief autonomy", "freedom of opinion"],
    "expression": ["communication", "right to speak", "artistic freedom", "expression of ideas"],
    "media": ["media independence", "journalistic freedom", "press autonomy", "right to information"],
    "information": ["right to knowledge", "information availability", "transparency", "access to data"],
    "association": ["right to gather", "group formation", "collective action", "association rights"],
    "Assembly, Demonstration, Picketing, and Petition": ["right to protest", "peaceful assembly", "public demonstration", "petitioning rights"],
    "Political": ["electoral rights", "civic participation", "political engagement", "voting rights"],
    "movement": ["mobility rights", "right to travel", "residential freedom", "movement liberties"],
    "Property": ["property rights", "ownership protection", "assets security", "right to possessions"],
    "Labour": ["employment rights", "worker protections", "fair labor practices", "collective bargaining"],
    "Environment": ["environmental rights", "sustainable surroundings", "right to a healthy environment", "protection of natural resources"],
    "Economic": ["right to health", "standard of living", "social welfare", "economic security"],
    "Language": ["cultural rights", "linguistic freedoms", "cultural expression", "heritage preservation"],
    "Family": ["family rights", "natural family unit", "societal foundation", "parental rights"],
    "Consumer": ["rights of consumers", "consumer protections", "entitlements for buyers", "purchaser rights"],
    "administrative": ["just administrative processes", "equitable administrative decisions", "lawful administrative action"],
    "justice": ["right to legal recourse", "legal access", "justice availability", "access to legal remedies"],
    "arrested": ["arrestee rights", "rights of detainees", "entitlements of arrested individuals", "protections for arrested persons"],
    "hearing": ["right to a fair trial", "equitable hearing", "just legal proceedings", "right to impartial adjudication"],
    "custody": ["entitlements of detainees", "protections for persons in custody", "fundamental freedoms for prisoners"],
    "Interpretation of this Part": ["explanation of this section", "clarification of this segment", "understanding of this chapter"],
    "Children": ["child rights", "children's entitlements", "rights of minors", "protections for children"],
    "disabilities": ["disability rights", "protections for disabled individuals", "rights of differently-abled persons"],
    "Youth": ["youth rights", "entitlements for young people", "protections for youth", "rights of adolescents"],
    "marginalised": ["minority rights", "rights of marginalized communities", "protections for marginalized populations"],
    "Older": ["elderly rights", "entitlements for older persons", "protections for seniors", "rights of the aged"],
    "emergency": ["emergency declaration", "crisis state", "public emergency", "emergency status"],
    "National Human Rights": ["National Human Rights Commission", "Human Rights and Equality Body", "Kenya Human Rights Authority"],
    "Principles of land": ["principles of land policy", "land management principles", "land policy guidelines", "equitable land administration"],
    "Classification of land": ["classification of land", "land categories", "types of land ownership", "land designation"],
    "Public land": ["public land", "government-owned land", "state property", "land for public use", "national land assets", "public landholding"],
    "Community land": ["community land", "ethnic group land", "cultural landholdings", "land for community use", "community owned land"],
    "Private land": ["private land", "individual landholding", "personal property", "leased land", "freehold land", "privately owned land"],
    "Landholding" : ["non-citizen ownership", "foreign lease", "alien land tenure", "leasehold limitation", "property by non-citizens"],
    "Regulation of land" : ["land governance", "land use policy", "property regulation", "land planning control", "land oversight"],
    "land Commission" : ["land authority", "land management board", "public land commission", "land governance body", "land policy agency"],
    "Legislation on land" : ["land laws", "land legislation", "property laws", "land-use regulation", "statutory land provisions", "land act"],
    "Obligations in respect of the environment" : ["environmental duty", "ecological obligations", "biodiversity duty", "conservation mandate"],
    "Enforcement of environmental rights" : ["environmental justice", "ecological redress", "sustainability enforcement", "ecosystem law enforcement"],
    "natural resource" : ["natural resource contracts", "resource exploitation deals", "resource use agreements", "environmental concessions"],
    "Legislation relating to the environment" : ["environmental laws", "ecological legislation", "natural resource statutes", "green policy enactments"],
    "Responsibilities of leadership": ["Leadership obligations", "Duties of leadership", "Leadership responsibilities"],
    "Oath": ["Swearing-in of State officers", "State officer oath", "State office affirmation"],
    "Conduct": ["Behavior of State officers", "State officer conduct", "Ethics for State officers"],
    "Financial probity": ["State officer financial integrity", "Monetary probity of officers", "Fiscal responsibility of State officers"],
    "Restriction": ["Limitations on State officers", "State officer restrictions", "Employment restrictions for officers"],
    "Citizenship": ["Citizenship eligibility for leaders", "Leadership and nationality", "State office citizenship requirements"],
    "ethics and anti-corruption": ["Anti-corruption commission laws", "Establishing ethics commission", "Laws for ethics enforcement"],
    "Legislation on leadership": ["Leadership laws", "Regulations on leadership", "Legislation governing leadership"]
}

sections = combined_sections

# QA mapping
qa_mapping = {
    "fundamental freedoms": ("fundamental freedoms"),
    "Application of bill": ("Application of bill"),
    "Implementation of rights": ("Implementation of rights"),
    "courts": ("courts"),
    "Limitation of rights": ("Limitation of rights"),
    "Fundamental rights": ("Fundamental rights"),
    "life": ("life"),
    "Equality": ("Equality"),
    "dignity": ("dignity"),
    "security": ("security"),
    "Slavery": ("Slavery"),
    "Privacy": ("Privacy"),
    "conscience": ("conscience"),
    "expression": ("expression"),
    "media": ("media"),
    "information": ("information"),
    "association": ("association"),
    "Assembly, Demonstration, Picketing, and Petition": ("Assembly, Demonstration, Picketing, and Petition"),
    "Political": ("Political"),
    "movement": ("movement"),
    "property": ("property"),
    "Labour": ("Labour"),
    "Environment": (""),
    "Economic": ("Economic"),
    "Language": ("Language"),
    "Family": ("Family"),
    "Consumer": ("Consumer"),
    "administrative": ("administrative"),
    "justice": ("justice"),
    "arrested": ("arrested"),
    "hearing": ("hearing"),
    "custody": ("custody"),
    "Interpretation of this Part": ("Interpretation of this Part"),
    "Children": ("Children"),
    "disabilities": ("disabilities"),
    "Youth": ("Youth"),
    "marginalised": ("marginalised"),
    "Older": ("Older"),
    "emergency": ("emergency"),
    "National Human Rights": ("National Human Rights"),
    "principles of land": ("principles of land"),
    "classification of land": ("classification of land"),
    "public land": ("public land"),
    "community land": ("community land"),
    "private land": ("private land"),
    "Landholding": ("Landholding"),
    "Regulation of land": ("Regulation of land"),
    "Land Commission": ("Land Commission"),
    "Legislation on land": ("Legislation on land"),
    "Obligations in respect of the environment": ("Obligations in respect of the environment"),
    "Enforcement of environmental rights": ("Enforcement of environmental rights"),
    "natural resource": ("natural resource"),
    "Legislation relating to the environment": ("Legislation relating to the environment"),
    "Responsibilities of leadership": ("Responsibilities of leadership"),
    "Oath": ("Oath"),
    "Conduct": ("Conduct"),
    "Financial probity": ("Financial probity"),
    "Restriction": ("Restriction"),
    "Citizenship": ("Citizenship"),
    "ethics and anti-corruption": ("ethics and anti-corruption"),
    "Legislation on leadership": ("Legislation on leadership")
}


# Preprocess the query
def preprocess_query(query):
    doc = nlp(query)
    tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(tokens)

# Function to correct the spelling
def correct_spelling(processed_query):
    spell = SpellChecker()
    words = processed_query.split()
    # Find misspelled words
    misspelled_words = spell.unknown(words)

    corrected_words = []
    for word in words:
        # Correct the word if it's misspelled
        if word in misspelled_words:
            corrected_word = spell.correction(word)  # Get the most likely correction
            corrected_words.append(corrected_word)
        else:
            corrected_words.append(word)

    # Reconstruct the initial sentence
    corrected_input = " ".join(corrected_words)
    return corrected_input

# Match the words with synonym support
def match_with_synonyms(query, qa_mapping, synonyms, threshold=70):
    processed_query = preprocess_query(query)
    logging.debug(f"Processed Query: {processed_query}")  # Debugging line

    # Correct spelling in the processed query
    corrected_query = correct_spelling(processed_query)
    logging.debug(f"Corrected Query: {corrected_query}")  # Debugging line

    for key, value in qa_mapping.items():
        logging.debug(f"Checking key: {key}, value: {value}")  # Debugging line
        for synonym in synonyms.get(key, [key]):
            logging.debug(f"Trying synonym: {synonym}")  # Debugging line
            if synonym in corrected_query:
                logging.debug(f"Match found with synonym: {synonym}")  # Debugging line
                return value  # Only return section value of the key
            
            # Check for fuzzy matching with the synonym using the threshold parameter
            if fuzz.ratio(synonym, corrected_query) > threshold:
                logging.debug(f"Fuzzy match found with synonym: {synonym}")  # Debugging line
                return value  # Return the key for the section
    
    logging.debug("No match found")  # Debugging line if no match is found
    return None

# Answer function with synonym and fuzzy matching
def answer_question_nlp(query, sections, qa_mapping, synonyms, threshold=70):
    section_key = match_with_synonyms(query, qa_mapping, synonyms, threshold)
    
    if section_key:
        # Retrieve the relevant section from the specified chapter
        return sections.get(section_key, "Section not found.")
    
    logging.error("No answer found for the question.")  # Log an error if no answer is found
    return "Sorry, I couldn't find an answer to your question."

# Sample usage
if __name__ == "__main__":
    user_query = "What is right to speak?"
    threshold_value = 75  # Adjust this value as needed
    answer = answer_question_nlp(user_query, sections, qa_mapping, synonyms, threshold=threshold_value)
    print(answer)
# Out:
# 2024-10-31 02:14:35,413 - DEBUG - Processed Query: right speak
# 2024-10-31 02:14:35,711 - DEBUG - Corrected Query: right speak
# 2024-10-31 02:14:35,711 - DEBUG - Checking key: fundamental freedoms, value: fundamental freedoms
# 2024-10-31 02:14:35,711 - DEBUG - Trying synonym: fundamental freedoms
# 2024-10-31 02:14:35,711 - DEBUG - Trying synonym: human rights
# 2024-10-31 02:14:35,719 - DEBUG - Trying synonym: basic rights
# 2024-10-31 02:14:35,722 - DEBUG - Trying synonym: constitutional rights
# 2024-10-31 02:14:35,726 - DEBUG - Checking key: Application of bill, value: Application of bill
# 2024-10-31 02:14:35,728 - DEBUG - Trying synonym: application of rights
# 2024-10-31 02:14:35,730 - DEBUG - Trying synonym: bill of rights enforcement
# 2024-10-31 02:14:35,732 - DEBUG - Trying synonym: enforcement of freedoms
# 2024-10-31 02:14:35,735 - DEBUG - Checking key: Implementation of rights, value: Implementation of rights
# ...

# %%
user_query = "What is State officer oath?"
threshold_value = 75  # Adjust this value as needed
answer = answer_question_nlp(user_query, sections, qa_mapping, synonyms, threshold=threshold_value)
print(answer)
# Out:
# 2024-10-31 02:14:35,909 - DEBUG - Processed Query: state officer oath
# 2024-10-31 02:14:36,198 - DEBUG - Corrected Query: state officer oath
# 2024-10-31 02:14:36,199 - DEBUG - Checking key: fundamental freedoms, value: fundamental freedoms
# 2024-10-31 02:14:36,199 - DEBUG - Trying synonym: fundamental freedoms
# 2024-10-31 02:14:36,205 - DEBUG - Trying synonym: human rights
# 2024-10-31 02:14:36,210 - DEBUG - Trying synonym: basic rights
# 2024-10-31 02:14:36,211 - DEBUG - Trying synonym: constitutional rights
# 2024-10-31 02:14:36,214 - DEBUG - Checking key: Application of bill, value: Application of bill
# 2024-10-31 02:14:36,225 - DEBUG - Trying synonym: application of rights
# 2024-10-31 02:14:36,229 - DEBUG - Trying synonym: bill of rights enforcement
# 2024-10-31 02:14:36,234 - DEBUG - Trying synonym: enforcement of freedoms
# 2024-10-31 02:14:36,237 - DEBUG - Checking key: Implementation of rights, value: Implementation of rights
# ...

# %%
user_query = "kindly explain what is political engagement?"
threshold_value = 75  # Adjust this value as needed
answer = answer_question_nlp(user_query, sections, qa_mapping, synonyms, threshold=threshold_value)
print(answer)
# Out:
# 2024-10-31 02:14:36,769 - DEBUG - Processed Query: kindly explain political engagement
# 2024-10-31 02:14:37,058 - DEBUG - Corrected Query: kindly explain political engagement
# 2024-10-31 02:14:37,058 - DEBUG - Checking key: fundamental freedoms, value: fundamental freedoms
# 2024-10-31 02:14:37,065 - DEBUG - Trying synonym: fundamental freedoms
# 2024-10-31 02:14:37,067 - DEBUG - Trying synonym: human rights
# 2024-10-31 02:14:37,069 - DEBUG - Trying synonym: basic rights
# 2024-10-31 02:14:37,071 - DEBUG - Trying synonym: constitutional rights
# 2024-10-31 02:14:37,073 - DEBUG - Checking key: Application of bill, value: Application of bill
# 2024-10-31 02:14:37,078 - DEBUG - Trying synonym: application of rights
# 2024-10-31 02:14:37,079 - DEBUG - Trying synonym: bill of rights enforcement
# 2024-10-31 02:14:37,083 - DEBUG - Trying synonym: enforcement of freedoms
# 2024-10-31 02:14:37,084 - DEBUG - Checking key: Implementation of rights, value: Implementation of rights
# ...

# %%
user_query = "what is constitutional rights?"
threshold_value = 75  # Adjust this value as needed
answer = answer_question_nlp(user_query, sections, qa_mapping, synonyms, threshold=threshold_value)
print(answer)
# Out:
# 2024-10-31 02:14:37,306 - DEBUG - Processed Query: constitutional right
# 2024-10-31 02:14:37,642 - DEBUG - Corrected Query: constitutional right
# 2024-10-31 02:14:37,643 - DEBUG - Checking key: fundamental freedoms, value: fundamental freedoms
# 2024-10-31 02:14:37,643 - DEBUG - Trying synonym: fundamental freedoms
# 2024-10-31 02:14:37,643 - DEBUG - Trying synonym: human rights
# 2024-10-31 02:14:37,650 - DEBUG - Trying synonym: basic rights
# 2024-10-31 02:14:37,653 - DEBUG - Trying synonym: constitutional rights
# 2024-10-31 02:14:37,653 - DEBUG - Fuzzy match found with synonym: constitutional rights
# Rights and fundamental freedoms.
# 19. (1) The Bill of Rights is an integral part of Kenya’s democratic
# state and is the framework for social, economic and cultural policies.
# (2) The purpose of recognising and protecting human rights and
# fundamental freedoms is to preserve the dignity of individuals and
# communities and to promote social justice and the realisation of the
# ...

# %%
user_query = "what is clarification of this segment?"
threshold_value = 75  # Adjust this value as needed
answer = answer_question_nlp(user_query, sections, qa_mapping, synonyms, threshold=threshold_value)
print(answer)
# Out:
# 2024-10-31 02:14:37,674 - DEBUG - Processed Query: clarification segment
# 2024-10-31 02:14:37,898 - DEBUG - Corrected Query: clarification segment
# 2024-10-31 02:14:37,899 - DEBUG - Checking key: fundamental freedoms, value: fundamental freedoms
# 2024-10-31 02:14:37,902 - DEBUG - Trying synonym: fundamental freedoms
# 2024-10-31 02:14:37,902 - DEBUG - Trying synonym: human rights
# 2024-10-31 02:14:37,904 - DEBUG - Trying synonym: basic rights
# 2024-10-31 02:14:37,906 - DEBUG - Trying synonym: constitutional rights
# 2024-10-31 02:14:37,908 - DEBUG - Checking key: Application of bill, value: Application of bill
# 2024-10-31 02:14:37,908 - DEBUG - Trying synonym: application of rights
# 2024-10-31 02:14:37,910 - DEBUG - Trying synonym: bill of rights enforcement
# 2024-10-31 02:14:37,911 - DEBUG - Trying synonym: enforcement of freedoms
# 2024-10-31 02:14:37,915 - DEBUG - Checking key: Implementation of rights, value: Implementation of rights
# ...
